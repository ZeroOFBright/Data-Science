# %% [markdown]
# <a href="https://colab.research.google.com/github/ZeroOFBright/Data-Science/blob/Rain-in-Australia/Rain_in_Australia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/drive/MyDrive/Kaggle/weatherAUS.csv")
df
# Out:
#               Date Location  MinTemp  ...  Temp3pm  RainToday  RainTomorrow
# 0       2008-12-01   Albury     13.4  ...     21.8         No            No
# 1       2008-12-02   Albury      7.4  ...     24.3         No            No
# 2       2008-12-03   Albury     12.9  ...     23.2         No            No
# 3       2008-12-04   Albury      9.2  ...     26.5         No            No
# 4       2008-12-05   Albury     17.5  ...     29.7         No            No
# ...            ...      ...      ...  ...      ...        ...           ...
# 145455  2017-06-21    Uluru      2.8  ...     22.4         No            No
# 145456  2017-06-22    Uluru      3.6  ...     24.5         No            No
# 145457  2017-06-23    Uluru      5.4  ...     26.1         No            No
# 145458  2017-06-24    Uluru      7.8  ...     26.0         No            No
# 145459  2017-06-25    Uluru     14.9  ...     20.9         No           NaN
#
# [145460 rows x 23 columns]

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
df["WindGustDir"].dtypes.kind
# Out:
# 'O'

# %%
num = df[["Cloud9am","Cloud3pm"]]
num = num.fillna(num.mean())
num
# Out:
#         Cloud9am  Cloud3pm
# 0       8.000000   4.50993
# 1       4.447461   4.50993
# 2       4.447461   2.00000
# 3       4.447461   4.50993
# 4       7.000000   8.00000
# ...          ...       ...
# 145455  4.447461   4.50993
# 145456  4.447461   4.50993
# 145457  4.447461   4.50993
# 145458  3.000000   2.00000
# 145459  8.000000   8.00000
#
# [145460 rows x 2 columns]

# %%
test = df.apply(lambda x: x.fillna(round(x.mean())) if x.dtype.kind in "iufc" else x.fillna(x.mode().astype(str)) )
test.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp              0
# MaxTemp              0
# Rainfall             0
# Evaporation          0
# Sunshine             0
# WindGustDir      10326
# WindGustSpeed        0
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am         0
# WindSpeed3pm         0
# Humidity9am          0
# Humidity3pm          0
# Pressure9am          0
# Pressure3pm          0
# Cloud9am             0
# Cloud3pm             0
# Temp9am              0
# Temp3pm              0
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp              0
# MaxTemp              0
# Rainfall             0
# Evaporation          0
# Sunshine             0
# WindGustDir      10326
# WindGustSpeed        0
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am         0
# WindSpeed3pm         0
# Humidity9am          0
# Humidity3pm          0
# Pressure9am          0
# Pressure3pm          0
# Cloud9am             0
# Cloud3pm             0
# Temp9am              0
# Temp3pm              0
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
df["WindGustDir"].mode()
# Out:
# 0    W
# dtype: object

# %%
# # clean = df[df["RainToday"].notna()]
# # clean = clean[clean["RainTomorrow"].notna()]

# clean = df[df[["RainToday","RainTomorrow"]].notna()]
# clean

# %%
clean2 = df.dropna(subset=["RainToday","RainTomorrow"])
clean2.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp            468
# MaxTemp            307
# Rainfall             0
# Evaporation      59694
# Sunshine         66805
# WindGustDir       9163
# WindGustSpeed     9105
# WindDir9am        9660
# WindDir3pm        3670
# WindSpeed9am      1055
# WindSpeed3pm      2531
# Humidity9am       1517
# Humidity3pm       3501
# Pressure9am      13743
# Pressure3pm      13769
# Cloud9am         52625
# Cloud3pm         56094
# Temp9am            656
# Temp3pm           2624
# RainToday            0
# RainTomorrow         0
# dtype: int64

# %%
clean2 = clean2.apply(lambda x: x.fillna(round(x.mean(),1)) if x.dtype.kind in "iufc" else x.fillna(x.mode()[0]))
clean2.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %%
clean2
# Out:
#               Date Location  MinTemp  ...  Temp3pm  RainToday  RainTomorrow
# 0       2008-12-01   Albury     13.4  ...     21.8         No            No
# 1       2008-12-02   Albury      7.4  ...     24.3         No            No
# 2       2008-12-03   Albury     12.9  ...     23.2         No            No
# 3       2008-12-04   Albury      9.2  ...     26.5         No            No
# 4       2008-12-05   Albury     17.5  ...     29.7         No            No
# ...            ...      ...      ...  ...      ...        ...           ...
# 145454  2017-06-20    Uluru      3.5  ...     20.9         No            No
# 145455  2017-06-21    Uluru      2.8  ...     22.4         No            No
# 145456  2017-06-22    Uluru      3.6  ...     24.5         No            No
# 145457  2017-06-23    Uluru      5.4  ...     26.1         No            No
# 145458  2017-06-24    Uluru      7.8  ...     26.0         No            No
#
# [140787 rows x 23 columns]
